# %% [markdown]
# # Practicing Creating table in IBM DB2

# %%
# !pip install sqlalchemy==1.3.9 
# !pip install ibm_db_sa
# Out:
# ...
#   Using cached SQLAlchemy-1.3.9-cp37-cp37m-win_amd64.whl
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.23
#     Uninstalling SQLAlchemy-1.3.23:
# WARNING: Ignoring invalid distribution -lalchemy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -lalchemy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -qlalchemy (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -egex (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
from sqlalchemy import create_engine

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://mgr61801:aG6rnocuLnVjRZCo@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb?security=SSL
cnx = create_engine('ibm_db_sa://mgr61801:aG6rnocuLnVjRZCo@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb?security=SSL').connect()

# %%
# %%sql
# CREATE TABLE TestTable1 (
#      Serial_number INT PRIMARY KEY NOT NULL,
#      Name VARCHAR(20) NOT NULL,
#      Name1 VARCHAR(20) NOT NULL,
#      Name2 VARCHAR(20) NOT NULL,
#      Name3 VARCHAR(20) NOT NULL
# )
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.
# []

# %%
# %%sql
# insert into testtable1(
#     serial_number, name, name1, name2, name3)
# values
#     (1,'sanket' ,'prada', 'waghya', 'jigar'),
#     (2,'sanket1' ,'prada1', 'waghya1', 'jigar1');
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# 2 rows affected.
# []

# %%
a = %sql select * from testtable1
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.

# %%
import random
import string
a_list = []
for i in range(5):
    one = ''.join(random.choices(string.ascii_uppercase + string.digits, k = 5))
    two = ''.join(random.choices(string.ascii_uppercase + string.digits, k = 5))
    three = ''.join(random.choices(string.ascii_uppercase + string.digits, k = 5))
    four = ''.join(random.choices(string.ascii_uppercase + string.digits, k = 5))
    a_list.append((i+3,one, two , three, four))   
a_list
# Out:
# [(3, '7IMF7', '8NMTC', 'XCL66', 'KZUD3'),
#  (4, 'GY4T8', 'PC4SI', 'XRTSK', 'Y0O4J'),
#  (5, '5DNIQ', 'FKIZT', 'Q63GC', 'CS4MF'),
#  (6, 'Q0SCT', 'BBLTU', 'WFD5R', 'PJHQU'),
#  (7, '31ULI', '66BKA', 'M3ESZ', 'XKFD5')]

# %%
# %%sql
# insert into testtable1(serial_number, name, name1, name2, name3) values (3, '7IMF7', '8NMTC', 'XCL66', 'KZUD3'),
#  (4, 'GY4T8', 'PC4SI', 'XRTSK', 'Y0O4J'),
#  (5, '5DNIQ', 'FKIZT', 'Q63GC', 'CS4MF'),
#  (6, 'Q0SCT', 'BBLTU', 'WFD5R', 'PJHQU'),
#  (7, '31ULI', '66BKA', 'M3ESZ', 'XKFD5');
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# 5 rows affected.
# []

# %%
a
# Out:
# [(1, 'sanket', 'prada', 'waghya', 'jigar'),
#  (2, 'sanket1', 'prada1', 'waghya1', 'jigar1'),
#  (3, '7IMF7', '8NMTC', 'XCL66', 'KZUD3'),
#  (4, 'GY4T8', 'PC4SI', 'XRTSK', 'Y0O4J'),
#  (5, '5DNIQ', 'FKIZT', 'Q63GC', 'CS4MF'),
#  (6, 'Q0SCT', 'BBLTU', 'WFD5R', 'PJHQU'),
#  (7, '31ULI', '66BKA', 'M3ESZ', 'XKFD5')]

# %%
type(a)
# Out:
# sql.run.ResultSet

# %%
import pandas as pd
xx = pd.read_sql_table('testtable1', cnx)

# %%
xx.to_csv("kanda.csv")

# %%
xx.to_sql("testtable2", cnx)

# %%
# %sql select * from testtable2;
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.
# [(0, 1, 'sanket', 'prada', 'waghya', 'jigar'),
#  (1, 2, 'sanket1', 'prada1', 'waghya1', 'jigar1'),
#  (2, 3, '7IMF7', '8NMTC', 'XCL66', 'KZUD3'),
#  (3, 4, 'GY4T8', 'PC4SI', 'XRTSK', 'Y0O4J'),
#  (4, 5, '5DNIQ', 'FKIZT', 'Q63GC', 'CS4MF'),
#  (5, 6, 'Q0SCT', 'BBLTU', 'WFD5R', 'PJHQU'),
#  (6, 7, '31ULI', '66BKA', 'M3ESZ', 'XKFD5')]

# %%
# to rop a talbe in sql database
#%sql drop table testtable2;
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.
# []

# %%
# %sql select * from testtable1 as t , petrescue as p where t.serial_number = p.quantity;
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.
# [(3, '7IMF7', '8NMTC', 'XCL66', 'KZUD3', 2, 'Dog', 3, Decimal('666.66'), datetime.date(2018, 6, 1)),
#  (1, 'sanket', 'prada', 'waghya', 'jigar', 3, 'Dog', 1, Decimal('100.00'), datetime.date(2018, 6, 4)),
#  (2, 'sanket1', 'prada1', 'waghya1', 'jigar1', 4, 'Parrot', 2, Decimal('50.00'), datetime.date(2018, 6, 4)),
#  (1, 'sanket', 'prada', 'waghya', 'jigar', 5, 'Dog', 1, Decimal('75.75'), datetime.date(2018, 6, 10)),
#  (6, 'Q0SCT', 'BBLTU', 'WFD5R', 'PJHQU', 6, 'Hamster', 6, Decimal('60.60'), datetime.date(2018, 6, 11)),
#  (1, 'sanket', 'prada', 'waghya', 'jigar', 7, 'Cat', 1, Decimal('44.44'), datetime.date(2018, 6, 11)),
#  (2, 'sanket1', 'prada1', 'waghya1', 'jigar1', 9, 'Dog', 2, Decimal('222.22'), datetime.date(2018, 6, 15))]

# %%
# %sql select coltype, length from sysibm.syscolumns where TBNAME = 'petrescue'
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.
# []

# %%
# %sql select * from chicago_crime_data
# Out:
#  * ibm_db_sa://mgr61801:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb
# Done.
# [(3512276, 'HK587712', datetime.date(2004, 8, 28), '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', datetime.date(2004, 6, 26), '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', datetime.date(2011, 4, 4), '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 'FALSE', 'FALSE', 221, 2, 3, 38, '6', 1177436, 1876313, 2011, Decimal('41.81593313'), Decimal('-87.62464213'), '(41.815933131, -87.624642127)'),
# ...
