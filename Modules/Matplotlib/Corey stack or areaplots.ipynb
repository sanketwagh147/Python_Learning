# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
minutes = list(range(1,10))
minutes
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
pla1 = np.random.randint(1,5,9)
pla2 = np.random.randint(1,5,9)
pla3 = np.random.randint(1,5,9)

# %%
plt.stackplot(minutes,pla1, pla2, pla3, labels=["1", "2", "3"])
plt.legend(loc=(0.07,0.05))
plt.show()>

# %%
plt.stackplot(minutes,pla1, pla2, pla3, labels=["1", "2", "3"])
plt.legend(loc=(0.07,0.05))

plt.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
