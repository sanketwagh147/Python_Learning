# %% [markdown]
# # Data Analsis 102

# %%
import pandas as pd
import numpy as np

# %%
filename = r"clean_df.csv"

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

# %%
df = pd.read_csv(filename)

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0             0          3                122  alfa-romero          two
# 1             1          3                122  alfa-romero          two
# 2             2          1                122  alfa-romero          two
# 3             3          2                164         audi         four
# 4             4          2                164         audi         four
# ..          ...        ...                ...          ...          ...
# 196         196         -1                 95        volvo         four
# 197         197         -1                 95        volvo         four
# 198         198         -1                 95        volvo         four
# 199         199         -1                 95        volvo         four
# 200         200         -1                 95        volvo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
drive_wheel_counts = df[["drive-wheels"]].value_counts().to_frame()

# %%
drive_wheel_counts
# Out:
#                 0
# drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0             0          3                122  alfa-romero          two
# 1             1          3                122  alfa-romero          two
# 2             2          1                122  alfa-romero          two
# 3             3          2                164         audi         four
# 4             4          2                164         audi         four
# ..          ...        ...                ...          ...          ...
# 196         196         -1                 95        volvo         four
# 197         197         -1                 95        volvo         four
# 198         198         -1                 95        volvo         four
# 199         199         -1                 95        volvo         four
# 200         200         -1                 95        volvo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
drive_wheel_counts.rename(columns ={"drive-wheels": "Type of drive",0:"Count"}, inplace = True)
drive_wheel_counts
# Out:
#               Count
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8

# %%
drive_wheel_counts.rename({"fwd": "Front", "rwd": "Rear", "4wd": "Four Wheel" }, inplace = True)

# %%
drive_wheel_counts
# Out:
#               Count
# drive-wheels
# Front           118
# Rear             75
# Four Wheel        8

# %%
drive_wheel_counts
# Out:
#               Count
# drive-wheels
# Front           118
# Rear             75
# Four Wheel        8

# %%
import seaborn as sns
import re
import matplotlib.pyplot as plt

# %%
# for i,v in enumerate(df["price"]):
#     if re.search(r"[^0-9]+" ,df["price"][i]):
#         print(i,v)
#         df.at['C', 'x']

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make num-of-doors  \
# 0             0          3                122  alfa-romero          two
# 1             1          3                122  alfa-romero          two
# 2             2          1                122  alfa-romero          two
# 3             3          2                164         audi         four
# 4             4          2                164         audi         four
# ..          ...        ...                ...          ...          ...
# 196         196         -1                 95        volvo         four
# 197         197         -1                 95        volvo         four
# 198         198         -1                 95        volvo         four
# 199         199         -1                 95        volvo         four
# 200         200         -1                 95        volvo         four
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# ...

# %%
# df["price"].replace("?", np.nan, inplace = True)
# df["price"] = df["price"].astype("float")

# %%
sns.boxplot(x = "drive-wheels", y="price", data = df)
plt.show()

# %%
df["engine-size"].dtype
# Out:
# dtype('int64')

# %%
y = df["price"]
x = df["engine-size"]
plt.scatter(x,y)
plt.title("SCatterplot of Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()

# %%
df_1 = df[['drive-wheels', 'body-style', 'price']]
df_1
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]

# %%
df_1_group = df_1.groupby(["drive-wheels", "body-style"], as_index = False).mean()
df_1_group
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %%
df_1_group.to_excel("df_1_group.xlsx")

# %%
df_1_pivot = df_1_group.pivot(index = 'drive-wheels', columns= 'body-style')
df_1_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
plt.pcolor(df_1_pivot, cmap = "RdBu")
plt.colorbar()
plt.show()

# %%
file2 = "testgroupby.csv"
df_3 = pd.read_csv(file2)

# %%
df_3
# Out:
#    type  color  price
# 0   cat  white     12
# 1   cat  white     13
# 2   cat  white     13
# 3   cat  black     13
# 4   cat  black     14
# 5   cat  black     15
# 6   dog  black     12
# 7   dog  green     17
# 8   dog  green     12
# 9   dog  green     14
# 10  dog  green     22
# 11  dog  alien     20
# 12  dog  alien     25

# %%
df3_groupby = df_3.groupby(["type", "color"], as_index = False).mean()

# %%
df3_pivot = df3_groupby.pivot(index = 'type', columns= 'color')
df3_pivot
# Out:
#       price
# color alien black  green      white
# type
# cat     NaN  14.0    NaN  12.666667
# dog    22.5  12.0  16.25        NaN

# %%
plt.pcolor(df3_pivot, cmap = "RdBu")
plt.colorbar()
plt.show()
grouped_pivot = df3_pivot

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %%
sns.regplot(x="engine-size", y="price", data = df)
plt.ylim(0,)
plt.show()

# %%
sns.regplot(x='city-mpg', y="price", data = df)
plt.ylim(0,)
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized-losses', 'make', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-L/100km', 'price',
#        'city-L/100km', 'horsepower-binned', 'fuel-type-diesel',
#        'fuel-type-gas', 'std_aspiration', 'turbo_aspiration'],
#       dtype='object')
