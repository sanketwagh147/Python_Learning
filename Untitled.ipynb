# %%
a_list = list(range(32))

# %%
c = list(enumerate(a_list))
I = iter(c)
I.__next__()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-31-b94cb488af83> in <module>
#       1 c = list(enumerate(a_list))
#       2 I = iter(c)
# ----> 3 I.__next__()
#
# StopIteration:

# %%
E = list('spam')

# %%
I = iter(E)

# %%
I.__next__()
# Out:
# 's'

# %%
next(I)
# Out:
# 'p'

# %%
a_list = [1,2,3]
b_list = [4,5,6]
l = [a+b for a in a_list for b in b_list if b == 6]

# %%
l
# Out:
# [7, 8, 9]

# %%
def fun(a,b,c):
    """
    this is function in editor and then move it to jupyter notebook
    """
    return a+b+c # return

# %%
print(fun(1,2,3))
print(fun.__doc__)
# Out:
# 6
#
#     this is function in editor and then move it to jupyter notebook

# %%
z =  zip(a_list,b_list)

# %%
next(z)
# Out:
# (1, 4)

# %%
dd = iter(l)
next(dd)
# Out:
# 7

# %%
# Out:
# 'Built-in mutable sequence.\n\nIf no argument is given, the constructor creates a new empty list.\nThe argument must be an iterable if specified.'

# %%
a_string  = "Kanda"
a_string.center(11)
# Out:
# '   Kanda   '

# %%
import docstrings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-79-9ad1c2a4b702> in <module>
# ----> 1 import docstrings
#
# ModuleNotFoundError: No module named 'docstrings'

# %%
def square(x):
    """ 
    function documentation can we have your liver then  ds? 
    """ 
    return x ** 2 # square 
class Employee: 
    "class documentation" 
    pass 
print(square(4)) 
print(square.__doc__)
print(fun.__doc__)
# Out:
# 16
#
#     function documentation can we have your liver then  ds?

# %%
print(enumerate.__doc__)
# Out:
# Return an enumerate object.
#
#   iterable
#     an object supporting iteration
#
# The enumerate object yields pairs containing a count (from start, which
# defaults to zero) and a value yielded by the iterable argument.
#
# enumerate is useful for obtaining an indexed list:
#     (0, seq[0]), (1, seq[1]), (2, seq[2]), ...

# %%
print(str.swapcase.__doc__)
# Out:
# Convert uppercase characters to lowercase and lowercase characters to uppercase.

# %%
help(str.swapcase)
# Out:
# Help on method_descriptor:
#
# swapcase(self, /)
#     Convert uppercase characters to lowercase and lowercase characters to uppercase.

# %%
help('django'), help('email.message')
# Out:
# No Python documentation found for 'django'.
# Use help() to get the interactive help utility.
# Use help(str) for help on the str class.
#
# Help on module email.message in email:
#
# NAME
#     email.message - Basic message object for the email package object model.
#
# MODULE REFERENCE
#     https://docs.python.org/3.7/library/email.message
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.object
#         Message
#     MIMEPart(Message)
#         EmailMessage
#
#     class EmailMessage(MIMEPart)
#      |  EmailMessage(policy=None)
#      |
#      |  Basic message object.
#      |
#      |  A message object is defined as something that has a bunch of RFC 2822
# ...
