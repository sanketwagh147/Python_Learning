# %%
{
  "connection": {
    "cli": {
      "arguments": [
        [
          "-u",
          "mgr61801",
          "-p",
          "aG6rnocuLnVjRZCo",
          "--ssl",
          "--sslCAFile",
          "1dd14d0c-1b52-4f63-a606-53ecba28771d",
          "--authenticationDatabase",
          "admin",
          "--host",
          "0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198"
        ]
      ],
      "bin": "db2",
      "certificate": {
        "certificate_base64": "...",
        "name": "1dd14d0c-1b52-4f63-a606-53ecba28771d"
      },
      "composed": [
        "db2 -u mgr61801 -p aG6rnocuLnVjRZCo --ssl --sslCAFile 1dd14d0c-1b52-4f63-a606-53ecba28771d --authenticationDatabase admin --host 0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198"
      ],
      "environment": {},
      "type": "cli"
    },
    "db2": {
      "authentication": {
        "method": "direct",
        "password": "aG6rnocuLnVjRZCo",
        "username": "mgr61801"
      },
      "certificate": {
        "certificate_base64": "...",
        "name": "1dd14d0c-1b52-4f63-a606-53ecba28771d"
      },
      "composed": [
        "db2://mgr61801:aG6rnocuLnVjRZCo@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb?authSource=admin&replicaSet=replset"
      ],
      "database": "bludb",
      "host_ros": [
        "0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31372"
      ],
      "hosts": [
        {
          "hostname": "0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud",
          "port": 31198
        }
      ],
      "jdbc_url": [
        "jdbc:db2://0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/bludb:user=<userid>;password=<your_password>;sslConnection=true;"
      ],
      "path": "/bludb",
      "query_options": {
        "authSource": "admin",
        "replicaSet": "replset"
      },
      "replica_set": "replset",
      "scheme": "db2",
      "type": "uri"
    }
  },
  "instance_administration_api": {
    "deployment_id": "crn:v1:bluemix:public:dashdb-for-transactions:eu-gb:a/90b229f94bb14348875f7215c49d29df:f6e92e8b-5e01-413a-af7d-2868c4d0b8ab::",
    "instance_id": "crn:v1:bluemix:public:dashdb-for-transactions:eu-gb:a/90b229f94bb14348875f7215c49d29df:f6e92e8b-5e01-413a-af7d-2868c4d0b8ab::",
    "root": "https://apieugb.db2.cloud.ibm.com/v5/ibm"
  }
}

# %%
import ibm_db
import pandas as pd
import ibm_db_dbi as db

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "mgr61801"        # e.g. "abc12345"
dsn_pwd = "aG6rnocuLnVjRZCo"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "31198"                # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

#print the connection string to check correct values are specified
print(dsn)
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=BLUDB;HOSTNAME=0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud;PORT=31198;PROTOCOL=TCPIP;UID=mgr61801;PWD=aG6rnocuLnVjRZCo;SECURITY=SSL;

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# Connected to database:  BLUDB as user:  mgr61801 on host:  0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud

# %%
# Create Table
table_name = "Trucks"
sql_statement = f"""
CREATE TABLE {table_name}(Serial_No varchar(20) PRIMARY KEY NOT NULL,
Model varchar(20) NOT NULL,
Manufacturer varchar(20) NOT NULL,
Engine_Size varchar(20) NOT NULL,
Engine_Name varchar(20) NOT NULL,
Truck_Class varchar(20) NOT NULL)
"""
#conn is database server
ibm_db.exec_immediate(conn, f"Drop Table {table_name}")  # drops table in case it is already preseng in DB
ibm_db.exec_immediate(conn, sql_statement)

# %%
# Load data multiple rows
sql_statement2 = """ INSERT INTO Trucks(Serial_No, Model, Manufacturer, Engine_Size, Engine_Name, Truck_Class)
VALUES
('A1234', 'Lonestar1', 'International1', 'Trucks1', 'Cummins ISX151', 'Class 1'),
('A1235', 'Lonestar2', 'International2', 'Trucks2', 'Cummins ISX152', 'Class 2'),
('A1236', 'Lonestar3', 'International3', 'Trucks3', 'Cummins ISX153', 'Class 3'),
('A1237', 'Lonestar4', 'International4', 'Trucks4', 'Cummins ISX154', 'Class 4'),
('A1238', 'Lonestar5', 'International5', 'Trucks5', 'Cummins ISX155', 'Class 4'),
('A1239', 'Lonestar6', 'International6', 'Trucks6', 'Cummins ISX156', 'Class 6');"""
ibm_db.exec_immediate(conn, sql_statement2)

# %%
# get table from database using select
sql_statement3 ="""SELECT * FROM Trucks;"""
statement = ibm_db.exec_immediate(conn, sql_statement3)
ibm_db.fetch_both(statement)
# Out:
# {'SERIAL_NO': 'A1234',
#  0: 'A1234',
#  'MODEL': 'Lonestar1',
#  1: 'Lonestar1',
#  'MANUFACTURER': 'International1',
#  2: 'International1',
#  'ENGINE_SIZE': 'Trucks1',
#  3: 'Trucks1',
#  'ENGINE_NAME': 'Cummins ISX151',
#  4: 'Cummins ISX151',
#  'TRUCK_CLASS': 'Class 1',
#  5: 'Class 1'}

# %%
# import ibm_db
# import pandas as pd
# import ibm_db_dbi as db
pconn = db.Connection(conn)
df = pd.read_sql(sql_statement3, pconn)

# %%
df
# Out:
#   SERIAL_NO      MODEL    MANUFACTURER ENGINE_SIZE     ENGINE_NAME TRUCK_CLASS
# 0     A1234  Lonestar1  International1     Trucks1  Cummins ISX151     Class 1
# 1     A1235  Lonestar2  International2     Trucks2  Cummins ISX152     Class 2
# 2     A1236  Lonestar3  International3     Trucks3  Cummins ISX153     Class 3
# 3     A1237  Lonestar4  International4     Trucks4  Cummins ISX154     Class 4
# 4     A1238  Lonestar5  International5     Trucks5  Cummins ISX155     Class 4
# 5     A1239  Lonestar6  International6     Trucks6  Cummins ISX156     Class 6

# %% [markdown]
# Double-click **here** for the solution.
#
# <!-- -->
#
# %sql select MAX(Safety_Score) AS MAX_SAFETY_SCORE from SCHOOLS
#
# Correct answer: 99

# %% [markdown]
# Click Here for More
# <!--
# More details block
# -->

# %%
dir(ibm_db)
# Out:
# ['ATTR_CASE',
#  'CASE_LOWER',
#  'CASE_NATURAL',
#  'CASE_UPPER',
#  'IBM_DBClientInfo',
#  'IBM_DBConnection',
#  'IBM_DBServerInfo',
#  'IBM_DBStatement',
#  'PARAM_FILE',
#  'QUOTED_LITERAL_REPLACEMENT_OFF',
#  'QUOTED_LITERAL_REPLACEMENT_ON',
#  'SQL_API_SQLROWCOUNT',
#  'SQL_ATTR_AUTOCOMMIT',
#  'SQL_ATTR_CURRENT_SCHEMA',
#  'SQL_ATTR_CURSOR_TYPE',
#  'SQL_ATTR_INFO_ACCTSTR',
#  'SQL_ATTR_INFO_APPLNAME',
#  'SQL_ATTR_INFO_PROGRAMNAME',
#  'SQL_ATTR_INFO_USERID',
#  'SQL_ATTR_INFO_WRKSTNNAME',
#  'SQL_ATTR_QUERY_TIMEOUT',
#  'SQL_ATTR_ROWCOUNT_PREFETCH',
#  'SQL_ATTR_TRUSTED_CONTEXT_PASSWORD',
#  'SQL_ATTR_TRUSTED_CONTEXT_USERID',
#  'SQL_ATTR_USE_TRUSTED_CONTEXT',
#  'SQL_AUTOCOMMIT_OFF',
#  'SQL_AUTOCOMMIT_ON',
#  'SQL_BIGINT',
#  'SQL_BINARY',
#  'SQL_BIT',
#  'SQL_BLOB',
#  'SQL_BLOB_LOCATOR',
#  'SQL_BOOLEAN',
#  'SQL_CHAR',
#  'SQL_CLOB',
#  'SQL_CLOB_LOCATOR',
#  'SQL_CURSOR_DYNAMIC',
#  'SQL_CURSOR_FORWARD_ONLY',
#  'SQL_CURSOR_KEYSET_DRIVEN',
#  'SQL_CURSOR_STATIC',
# ...
