# %% [markdown]
# # Data Analysis 101

# %%
# !pip install pandas
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"ChicagoPublicSchools_Test.csv")

# %%
df.head(11)

# %%
df.NAME_OF_SCHOOL.nunique()
# Out:
# 9

# %%
df.dropna(subset =["City"], axis = 0, inplace=True)

# %%
df["Safety_Icon"].replace(np.nan, "whooo HOOO", inplace = True)

# %%
df.replace("Not Enough Data", "Zero")
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
# 5     610212                  Albany Park Multicultural Academy
# 6     609720                Albert G Lane Technical High School
# 7     610342            Albert R Sabin Elementary Magnet School
# 8     610524              Alcott High School for the Humanities
#
#           Street_Address     City Track_Schedule  \
# 0        615 W Kemper Pl  Chicago       Standard
# 1  7511 S South Shore Dr  Chicago        Track_E
# 3     4619 S Wolcott Ave  Chicago        Track_E
# 4        3630 S Wells St  Chicago       Standard
# 5      4929 N Sawyer Ave  Chicago       Standard
# 6      2501 W Addison St  Chicago       Standard
# ...

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
pd.get_dummies(df["Track_Schedule"])
# Out:
#    Standard  Track_E
# 0         1        0
# 1         0        1
# 3         0        1
# 4         1        0
# 5         1        0
# 6         1        0
# 7         1        0
# 8         1        0

# %%
df.columns
df['HEALTHY_SCHOOL_CERTIFIED'].value_counts()
# Out:
# No     6
# Yes    2
# Name: HEALTHY_SCHOOL_CERTIFIED, dtype: int64
