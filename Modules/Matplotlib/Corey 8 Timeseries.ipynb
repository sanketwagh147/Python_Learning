# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %%
# %matplotlib inline

# %%
plt.style.use('seaborn')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]
plt.plot_date(dates,y,linestyle="solid", marker=None)
plt.gcf().autofmt_xdate()
# data = pd.read_csv('data.csv')
# price_date = data['Date']
# price_close = data['Close']
date_format = mpl_dates.DateFormatter("%b, %d %Y")
plt.gca().xaxis.set_major_formatter(date_format)

# plt.title('Bitcoin Prices')
# plt.xlabel('Date')
# plt.ylabel('Closing Price')
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.

# %%
data = pd.read_csv(r"coreytimeseriesdata.csv")

# %%
# sort by dates
price_date = pd.to_datetime(data["Date"])
data.sort_values("Date", inplace=True)
price_close = data["Close"]

# %%
plt.plot_date(price_date, price_close, linestyle="solid")
plt.gcf().autofmt_xdate()
plt.title("Bitcoin Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price")
# Out:
# Text(0, 0.5, 'Closing Price')
