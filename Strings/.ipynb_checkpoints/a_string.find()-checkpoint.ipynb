# %% [markdown]
# Find the sub string in a string and returns its index else returns -1
# <br>
# data = "iam sanket and I am going to use find the sub-string in string variable called data"<br>
# sub_string = "sanket"<br>
# index_of_sub_string = data.find(sub_string, 0, 10)<br>
# print(index_of_sub_string)<br>
# #op: 42 ---the index location of s from sub-string<br>
# # index = data.index(sub_string)<br>
# # print(index)<br>
# print(data[43:])
